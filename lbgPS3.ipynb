# %%
import numpy as np
import matplotlib.pyplot as plt

def lbg_algorithm(data, num_codevectors, epsilon=0.01):
    """
    Implements the Linde-Buzo-Gray (LBG) algorithm for Vector Quantization.
    
    Parameters:
        data (ndarray): Data points (NxD) where N is the number of samples, D is the feature dimension.
        num_codevectors (int): Desired number of codevectors (clusters).
        epsilon (float): Perturbation factor for centroid splitting.

    Returns:
        codebook (ndarray): The final set of cluster centroids.
        assigned_clusters (ndarray): The final cluster assignments for each data point.
    """

    # Step 1: Initialize codebook with starting value. What might be a good choice with
    # the given data?
    codebook = 'value calculation here'

    while codebook.shape[0] < num_codevectors:
        pass
        # Step 2: Expand by splitting. See new_codevector() in blog post and apply to a + and - epsilon

        while True:
            pass
            
            # Step 3: Compute distances & assign clusters
            # Assign each data vector to the nearest codevector 
            # (nearest in terms of Euclidean distance or another chosen metric)
            distance = None
            assigned_clusters = None

            # Step 4: Update centroids (handling empty clusters) 
            # Complete For loop
            new_codebook = np.zeros_like(codebook)  # Placeholder for updated centroids
            
            # 4.1 Loop through each centroid
            # 4.2 Get points assigned to this centroid
            # 4.3 If the cluster has points assigned
            # 4.4 Compute mean
            # 4.5 Keep old centroid if empty cluster
            for i in range(len(codebook)): 
                pass

            # Step 5 Convergence check: If centroids do not change significantly, stop
                 
            codebook = new_codebook

    return codebook, assigned_clusters


def plot_clusters(data, codebook, assignments):
    plt.figure(figsize=(8, 8))
    
    # Scatter plot colored by cluster assignments
    plt.scatter(data[:, 0], data[:, 1], c=assignments, cmap='tab10', marker='.')
    
    # Plot the code vectors in the same color as their cluster
    for i, vector in enumerate(codebook):
        plt.scatter(vector[0], vector[1], s=100, edgecolors='black', linewidth=1.5, label=f'Code Vector {i}')
    
    plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
    plt.title("LBG Vector Quantization Clustering")
    plt.show()

# Generate Data
np.random.seed(42)
data = np.random.rand(100, 2)
num_codevectors = 8

# Run Algorithm
codebook, assignments = lbg_algorithm(data, num_codevectors)
plot_clusters(data, codebook, assignments)
